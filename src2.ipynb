# %%
pip install -r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt --upgrade
# Out:
# Requirement already satisfied: gitpython>=3.1.30 in c:\users\max01\anaconda3\lib\site-packages (from -r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 5)) (3.1.37)
# Collecting gitpython>=3.1.30 (from -r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 5))
#   Obtaining dependency information for gitpython>=3.1.30 from https://files.pythonhosted.org/packages/8d/c4/82b858fb6483dfb5e338123c154d19c043305b01726a67d89532b8f8f01b/GitPython-3.1.40-py3-none-any.whl.metadata
#   Downloading GitPython-3.1.40-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: matplotlib>=3.3 in c:\users\max01\anaconda3\lib\site-packages (from -r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 6)) (3.7.1)
# Collecting matplotlib>=3.3 (from -r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 6))
#   Obtaining dependency information for matplotlib>=3.3 from https://files.pythonhosted.org/packages/40/d9/c1784db9db0d484c8e5deeafbaac0d6ed66e165c6eb4a74fb43a5fa947d9/matplotlib-3.8.0-cp311-cp311-win_amd64.whl.metadata
#   Using cached matplotlib-3.8.0-cp311-cp311-win_amd64.whl.metadata (5.9 kB)
# Requirement already satisfied: numpy>=1.22.2 in c:\users\max01\anaconda3\lib\site-packages (from -r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 7)) (1.24.3)
# Collecting numpy>=1.22.2 (from -r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 7))
#   Obtaining dependency information for numpy>=1.22.2 from https://files.pythonhosted.org/packages/82/0f/3f712cd84371636c5375d2dd70e7514d264cec6bdfc3d7997a4236e9f948/numpy-1.26.1-cp311-cp311-win_amd64.whl.metadata
#   Downloading numpy-1.26.1-cp311-cp311-win_amd64.whl.metadata (61 kB)
#      ---------------------------------------- 0.0/61.2 kB ? eta -:--:--
#      ---------------------------------------- 61.2/61.2 kB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: opencv-python>=4.1.1 in c:\users\max01\anaconda3\lib\site-packages (from -r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 8)) (4.8.0.76)
# Collecting opencv-python>=4.1.1 (from -r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 8))
#   Obtaining dependency information for opencv-python>=4.1.1 from https://files.pythonhosted.org/packages/38/d2/3e8c13ffc37ca5ebc6f382b242b44acb43eb489042e1728407ac3904e72f/opencv_python-4.8.1.78-cp37-abi3-win_amd64.whl.metadata
#   Using cached opencv_python-4.8.1.78-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: Pillow>=7.1.2 in c:\users\max01\anaconda3\lib\site-packages (from -r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 9)) (9.4.0)
# Collecting Pillow>=7.1.2 (from -r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 9))
#   Obtaining dependency information for Pillow>=7.1.2 from https://files.pythonhosted.org/packages/b1/38/31def4109acd4db10672df6f806b175c0d21458f845ddc0890e43238ba7c/Pillow-10.1.0-cp311-cp311-win_amd64.whl.metadata
#   Downloading Pillow-10.1.0-cp311-cp311-win_amd64.whl.metadata (9.6 kB)
# Requirement already satisfied: psutil in c:\users\max01\anaconda3\lib\site-packages (from -r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 10)) (5.9.0)
# Collecting psutil (from -r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 10))
#   Obtaining dependency information for psutil from https://files.pythonhosted.org/packages/c5/b2/699c50fe0b0402a1ccb64ad71313bcb740e735008dd3ab9abeddbe148e45/psutil-5.9.6-cp37-abi3-win_amd64.whl.metadata
#   Downloading psutil-5.9.6-cp37-abi3-win_amd64.whl.metadata (22 kB)
# Requirement already satisfied: PyYAML>=5.3.1 in c:\users\max01\anaconda3\lib\site-packages (from -r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 11)) (6.0)
# Collecting PyYAML>=5.3.1 (from -r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 11))
#   Obtaining dependency information for PyYAML>=5.3.1 from https://files.pythonhosted.org/packages/b3/34/65bb4b2d7908044963ebf614fe0fdb080773fc7030d7e39c8d3eddcd4257/PyYAML-6.0.1-cp311-cp311-win_amd64.whl.metadata
#   Using cached PyYAML-6.0.1-cp311-cp311-win_amd64.whl.metadata (2.1 kB)
# Requirement already satisfied: requests>=2.23.0 in c:\users\max01\anaconda3\lib\site-packages (from -r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 12)) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\max01\anaconda3\lib\site-packages (from -r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 13)) (1.10.1)
# Collecting scipy>=1.4.1 (from -r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 13))
#   Obtaining dependency information for scipy>=1.4.1 from https://files.pythonhosted.org/packages/81/d7/d2537d51efb692d0c411e64267ba349e7668d40f5bc73cefe78ccd650dcd/scipy-1.11.3-cp311-cp311-win_amd64.whl.metadata
#   Using cached scipy-1.11.3-cp311-cp311-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: thop>=0.1.1 in c:\users\max01\anaconda3\lib\site-packages (from -r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 14)) (0.1.1.post2209072238)
# Requirement already satisfied: torch>=1.8.0 in c:\users\max01\anaconda3\lib\site-packages (from -r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 15)) (2.0.1)
# Collecting torch>=1.8.0 (from -r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 15))
#   Obtaining dependency information for torch>=1.8.0 from https://files.pythonhosted.org/packages/74/07/edce54779f5c3fe8ab8390eafad3d7c8190fce68f922a254ea77f4a94a99/torch-2.1.0-cp311-cp311-win_amd64.whl.metadata
#   Using cached torch-2.1.0-cp311-cp311-win_amd64.whl.metadata (25 kB)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\max01\anaconda3\lib\site-packages (from -r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 16)) (0.15.2)
# Collecting torchvision>=0.9.0 (from -r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 16))
#   Obtaining dependency information for torchvision>=0.9.0 from https://files.pythonhosted.org/packages/20/ac/ab6f42af83349e679b03c9bb18354740c6b58b17dba329fb408730230584/torchvision-0.16.0-cp311-cp311-win_amd64.whl.metadata
#   Using cached torchvision-0.16.0-cp311-cp311-win_amd64.whl.metadata (6.6 kB)
# Requirement already satisfied: tqdm>=4.64.0 in c:\users\max01\anaconda3\lib\site-packages (from -r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 17)) (4.65.0)
# Collecting tqdm>=4.64.0 (from -r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 17))
#   Obtaining dependency information for tqdm>=4.64.0 from https://files.pythonhosted.org/packages/00/e5/f12a80907d0884e6dff9c16d0c0114d81b8cd07dc3ae54c5e962cc83037e/tqdm-4.66.1-py3-none-any.whl.metadata
#   Using cached tqdm-4.66.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: ultralytics>=8.0.147 in c:\users\max01\anaconda3\lib\site-packages (from -r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 18)) (8.0.198)
# Collecting ultralytics>=8.0.147 (from -r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 18))
#   Obtaining dependency information for ultralytics>=8.0.147 from https://files.pythonhosted.org/packages/7e/52/c7cc8180e6224828b7fc194136e0308fa65b67faac26de86a967966162e0/ultralytics-8.0.200-py3-none-any.whl.metadata
#   Downloading ultralytics-8.0.200-py3-none-any.whl.metadata (31 kB)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\max01\anaconda3\lib\site-packages (from -r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 27)) (1.5.3)
# Collecting pandas>=1.1.4 (from -r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 27))
#   Obtaining dependency information for pandas>=1.1.4 from https://files.pythonhosted.org/packages/2d/5e/9213ea10ac473e2437dc2cb17323ddc0999997e2713d6a0b683b10773994/pandas-2.1.1-cp311-cp311-win_amd64.whl.metadata
#   Using cached pandas-2.1.1-cp311-cp311-win_amd64.whl.metadata (18 kB)
# Requirement already satisfied: seaborn>=0.11.0 in c:\users\max01\anaconda3\lib\site-packages (from -r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 28)) (0.12.2)
# Collecting seaborn>=0.11.0 (from -r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 28))
#   Obtaining dependency information for seaborn>=0.11.0 from https://files.pythonhosted.org/packages/7b/e5/83fcd7e9db036c179e0352bfcd20f81d728197a16f883e7b90307a88e65e/seaborn-0.13.0-py3-none-any.whl.metadata
#   Using cached seaborn-0.13.0-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: setuptools>=65.5.1 in c:\users\max01\anaconda3\lib\site-packages (from -r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 42)) (68.0.0)
# Collecting setuptools>=65.5.1 (from -r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 42))
#   Obtaining dependency information for setuptools>=65.5.1 from https://files.pythonhosted.org/packages/bb/26/7945080113158354380a12ce26873dd6c1ebd88d47f5bc24e2c5bb38c16a/setuptools-68.2.2-py3-none-any.whl.metadata
#   Using cached setuptools-68.2.2-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\max01\anaconda3\lib\site-packages (from gitpython>=3.1.30->-r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 5)) (4.0.10)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\max01\anaconda3\lib\site-packages (from matplotlib>=3.3->-r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 6)) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\max01\anaconda3\lib\site-packages (from matplotlib>=3.3->-r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 6)) (0.10.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\max01\anaconda3\lib\site-packages (from matplotlib>=3.3->-r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 6)) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\max01\anaconda3\lib\site-packages (from matplotlib>=3.3->-r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 6)) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\max01\anaconda3\lib\site-packages (from matplotlib>=3.3->-r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 6)) (23.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\max01\anaconda3\lib\site-packages (from matplotlib>=3.3->-r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 6)) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\max01\anaconda3\lib\site-packages (from matplotlib>=3.3->-r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 6)) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\max01\anaconda3\lib\site-packages (from requests>=2.23.0->-r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 12)) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\max01\anaconda3\lib\site-packages (from requests>=2.23.0->-r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 12)) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\max01\anaconda3\lib\site-packages (from requests>=2.23.0->-r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 12)) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\max01\anaconda3\lib\site-packages (from requests>=2.23.0->-r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 12)) (2022.12.7)
# Requirement already satisfied: filelock in c:\users\max01\anaconda3\lib\site-packages (from torch>=1.8.0->-r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 15)) (3.9.0)
# Requirement already satisfied: typing-extensions in c:\users\max01\anaconda3\lib\site-packages (from torch>=1.8.0->-r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 15)) (4.7.1)
# Requirement already satisfied: sympy in c:\users\max01\anaconda3\lib\site-packages (from torch>=1.8.0->-r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 15)) (1.11.1)
# Requirement already satisfied: networkx in c:\users\max01\anaconda3\lib\site-packages (from torch>=1.8.0->-r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 15)) (3.1)
# Requirement already satisfied: jinja2 in c:\users\max01\anaconda3\lib\site-packages (from torch>=1.8.0->-r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 15)) (3.1.2)
# Requirement already satisfied: fsspec in c:\users\max01\anaconda3\lib\site-packages (from torch>=1.8.0->-r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 15)) (2023.3.0)
# Requirement already satisfied: colorama in c:\users\max01\anaconda3\lib\site-packages (from tqdm>=4.64.0->-r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 17)) (0.4.6)
# Requirement already satisfied: py-cpuinfo in c:\users\max01\anaconda3\lib\site-packages (from ultralytics>=8.0.147->-r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 18)) (8.0.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\max01\anaconda3\lib\site-packages (from pandas>=1.1.4->-r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 27)) (2022.7)
# Collecting tzdata>=2022.1 (from pandas>=1.1.4->-r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 27))
#   Using cached tzdata-2023.3-py2.py3-none-any.whl (341 kB)
# Requirement already satisfied: six in c:\users\max01\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib>=3.3->-r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 6)) (1.16.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\max01\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython>=3.1.30->-r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 5)) (5.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\max01\anaconda3\lib\site-packages (from jinja2->torch>=1.8.0->-r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 15)) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\max01\anaconda3\lib\site-packages (from sympy->torch>=1.8.0->-r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 15)) (1.3.0)
# Downloading GitPython-3.1.40-py3-none-any.whl (190 kB)
#    ---------------------------------------- 0.0/190.6 kB ? eta -:--:--
#    ---------------------------------------- 190.6/190.6 kB 5.8 MB/s eta 0:00:00
# Using cached matplotlib-3.8.0-cp311-cp311-win_amd64.whl (7.6 MB)
# Downloading numpy-1.26.1-cp311-cp311-win_amd64.whl (15.8 MB)
#    ---------------------------------------- 0.0/15.8 MB ? eta -:--:--
#    - -------------------------------------- 0.6/15.8 MB 19.8 MB/s eta 0:00:01
#    --- ------------------------------------ 1.4/15.8 MB 18.1 MB/s eta 0:00:01
#    ----- ---------------------------------- 2.0/15.8 MB 16.2 MB/s eta 0:00:01
#    ------- -------------------------------- 2.8/15.8 MB 16.1 MB/s eta 0:00:01
#    -------- ------------------------------- 3.5/15.8 MB 15.9 MB/s eta 0:00:01
#    ---------- ----------------------------- 4.0/15.8 MB 15.0 MB/s eta 0:00:01
#    ----------- ---------------------------- 4.4/15.8 MB 14.7 MB/s eta 0:00:01
#    ----------- ---------------------------- 4.5/15.8 MB 12.5 MB/s eta 0:00:01
#    ------------ --------------------------- 4.9/15.8 MB 12.2 MB/s eta 0:00:01
#    -------------- ------------------------- 5.6/15.8 MB 12.4 MB/s eta 0:00:01
#    -------------- ------------------------- 5.9/15.8 MB 11.7 MB/s eta 0:00:01
#    ---------------- ----------------------- 6.5/15.8 MB 11.9 MB/s eta 0:00:01
#    ----------------- ---------------------- 6.8/15.8 MB 11.7 MB/s eta 0:00:01
#    ------------------ --------------------- 7.4/15.8 MB 11.6 MB/s eta 0:00:01
#    -------------------- ------------------- 8.2/15.8 MB 11.9 MB/s eta 0:00:01
#    ---------------------- ----------------- 8.8/15.8 MB 11.9 MB/s eta 0:00:01
#    ----------------------- ---------------- 9.2/15.8 MB 11.8 MB/s eta 0:00:01
#    ----------------------- ---------------- 9.4/15.8 MB 11.6 MB/s eta 0:00:01
#    ------------------------ --------------- 9.8/15.8 MB 11.2 MB/s eta 0:00:01
#    ------------------------- -------------- 10.2/15.8 MB 11.1 MB/s eta 0:00:01
#    --------------------------- ------------ 10.8/15.8 MB 10.9 MB/s eta 0:00:01
#    ---------------------------- ----------- 11.4/15.8 MB 10.7 MB/s eta 0:00:01
#    ------------------------------ --------- 11.9/15.8 MB 10.6 MB/s eta 0:00:01
#    ------------------------------- -------- 12.5/15.8 MB 10.6 MB/s eta 0:00:01
#    --------------------------------- ------ 13.1/15.8 MB 10.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 13.7/15.8 MB 10.4 MB/s eta 0:00:01
#    ------------------------------------- -- 14.6/15.8 MB 11.5 MB/s eta 0:00:01
#    -------------------------------------- - 15.4/15.8 MB 11.7 MB/s eta 0:00:01
#    ---------------------------------------  15.8/15.8 MB 11.7 MB/s eta 0:00:01
#    ---------------------------------------- 15.8/15.8 MB 11.1 MB/s eta 0:00:00
# Using cached opencv_python-4.8.1.78-cp37-abi3-win_amd64.whl (38.1 MB)
# Downloading Pillow-10.1.0-cp311-cp311-win_amd64.whl (2.6 MB)
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.6 MB 16.6 MB/s eta 0:00:01
#    ------------------ --------------------- 1.2/2.6 MB 18.5 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.9/2.6 MB 14.7 MB/s eta 0:00:01
#    ---------------------------------------  2.6/2.6 MB 15.1 MB/s eta 0:00:01
#    ---------------------------------------- 2.6/2.6 MB 13.8 MB/s eta 0:00:00
# Downloading psutil-5.9.6-cp37-abi3-win_amd64.whl (252 kB)
#    ---------------------------------------- 0.0/252.3 kB ? eta -:--:--
#    ------------------------------ --------- 194.6/252.3 kB 5.8 MB/s eta 0:00:01
#    ---------------------------------------- 252.3/252.3 kB 5.2 MB/s eta 0:00:00
# Using cached PyYAML-6.0.1-cp311-cp311-win_amd64.whl (144 kB)
# Using cached scipy-1.11.3-cp311-cp311-win_amd64.whl (44.1 MB)
# Using cached torch-2.1.0-cp311-cp311-win_amd64.whl (192.3 MB)
# Using cached torchvision-0.16.0-cp311-cp311-win_amd64.whl (1.3 MB)
# Using cached tqdm-4.66.1-py3-none-any.whl (78 kB)
# Downloading ultralytics-8.0.200-py3-none-any.whl (644 kB)
#    ---------------------------------------- 0.0/644.5 kB ? eta -:--:--
#    --------------------------------------- 644.5/644.5 kB 20.5 MB/s eta 0:00:00
# Using cached pandas-2.1.1-cp311-cp311-win_amd64.whl (10.6 MB)
# Using cached seaborn-0.13.0-py3-none-any.whl (294 kB)
# Using cached setuptools-68.2.2-py3-none-any.whl (807 kB)
# Installing collected packages: tzdata, tqdm, setuptools, PyYAML, psutil, Pillow, numpy, torch, scipy, pandas, opencv-python, gitpython, torchvision, matplotlib, seaborn, ultralytics
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.65.0
#     Uninstalling tqdm-4.65.0:
#       Successfully uninstalled tqdm-4.65.0
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 68.0.0
#     Uninstalling setuptools-68.0.0:
#       Successfully uninstalled setuptools-68.0.0
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 6.0
#     Uninstalling PyYAML-6.0:
#       Successfully uninstalled PyYAML-6.0
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.9.0
#     Uninstalling psutil-5.9.0:
#       Successfully uninstalled psutil-5.9.0
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not install packages due to an OSError: [WinError 5] 액세스가 거부되었습니다: 'C:\\Users\\max01\\anaconda3\\Lib\\site-packages\\~sutil\\_psutil_windows.cp311-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.

# %%
import torch

# Model
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')

# Image
im = 'https://ultralytics.com/images/zidane.jpg'

# Inference
results = model(im)

results.pandas().xyxy[0]
#      xmin    ymin    xmax   ymax  confidence  class    name
# 0  749.50   43.50  1148.0  704.5    0.874023      0  person
# 1  433.50  433.50   517.5  714.5    0.687988     27     tie
# 2  114.75  195.75  1095.0  708.0    0.624512      0  person
# 3  986.00  304.00  1028.0  420.0    0.286865     27     tie
# Out:
# c:\Users\max01\anaconda3\Lib\site-packages\torch\hub.py:286: UserWarning: You are about to download and run code from an untrusted repository. In a future release, this won't be allowed. To add the repository to your trusted list, change the command to {calling_fn}(..., trust_repo=False) and a command prompt will appear asking for an explicit confirmation of trust, or load(..., trust_repo=True), which will assume that the prompt is to be answered with 'yes'. You can also use load(..., trust_repo='check') which will only prompt for confirmation if the repo is not already trusted. This will eventually be the default behaviour
#   warnings.warn(
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to C:\Users\max01/.cache\torch\hub\master.zip
# YOLOv5  2023-10-21 Python-3.11.4 torch-2.0.1 CUDA:0 (NVIDIA GeForce RTX 2060 with Max-Q Design, 6144MiB)
#
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5s.pt to yolov5s.pt...
# 100%|██████████| 14.1M/14.1M [00:02<00:00, 7.05MB/s]
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# Adding AutoShape...
#          xmin        ymin         xmax        ymax  confidence  class    name
# 0  742.974854   48.395508  1141.844482  720.000000    0.881052      0  person
# 1  442.007629  437.522400   496.653992  709.973572    0.675213     27     tie
# 2  123.024231  193.287415   715.661987  719.723816    0.665815      0  person
# 3  982.803162  308.417358  1027.365845  419.987000    0.260076     27     tie

# %%
import cv2
import torch
from PIL import Image

# Model
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')

model.cuda()  # GPU

# Images
for f in 'zidane.jpg', 'bus.jpg':
    torch.hub.download_url_to_file('https://ultralytics.com/images/' + f, f)  # download 2 images
im1 = Image.open('zidane.jpg')  # PIL image
im2 = cv2.imread('bus.jpg')[..., ::-1]  # OpenCV image (BGR to RGB)

# Inference
results = model([im1, im2], size=640) # batch of images

# Results
results.print()  
results.save()  # or .show()

results.xyxy[0]  # im1 predictions (tensor)
results.pandas().xyxy[0]  # im1 predictions (pandas)
#      xmin    ymin    xmax   ymax  confidence  class    name
# 0  749.50   43.50  1148.0  704.5    0.874023      0  person
# 1  433.50  433.50   517.5  714.5    0.687988     27     tie
# 2  114.75  195.75  1095.0  708.0    0.624512      0  person
# 3  986.00  304.00  1028.0  420.0    0.286865     27     tie
# Out:
# Using cache found in C:\Users\max01/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2023-10-21 Python-3.11.4 torch-2.0.1 CUDA:0 (NVIDIA GeForce RTX 2060 with Max-Q Design, 6144MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# Adding AutoShape...
# 100%|██████████| 165k/165k [00:00<00:00, 1.37MB/s]
# 100%|██████████| 476k/476k [00:00<00:00, 2.42MB/s]
# image 1/2: 720x1280 2 persons, 2 ties
# image 2/2: 1080x810 4 persons, 1 bus
# Speed: 11.0ms pre-process, 11.5ms inference, 2.0ms NMS per image at shape (2, 3, 640, 640)
# Saved 2 images to runs\detect\exp2
#          xmin        ymin         xmax        ymax  confidence  class    name
# 0  742.550171   48.037018  1141.204712  716.641846    0.881825      0  person
# 1  442.059479  437.528076   496.809357  709.838989    0.687342     27     tie
# 2  125.191406  193.680603   711.992371  713.047058    0.639421      0  person
# 3  982.893005  308.356750  1027.368652  420.091736    0.262013     27     tie
